# %%
from PIL import Image
import numpy as np

img1=Image.open('abc 2.jpg').convert('L')
img2=Image.open('flowers2.jpg').convert('L')

#img1.show()
#img2.show()

img1_arr=np.array(img1)
img2_arr=np.array(img2)

result=abs(img1_arr - img2_arr)
(Image.fromarray(result)).show()

# %%
img1_arr=np.array(img1)
img2_arr=np.array(img2)

result=(img1_arr+img2_arr)/2

display(Image.fromarray(result).convert('L'))
# Out:
# <PIL.Image.Image image mode=L size=259x194 at 0x4C547B8>
